# %% [markdown]
# <a href="https://colab.research.google.com/github/Roman-Lunin/MPA-MLF/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Import libraries
import zipfile
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing import image

# %%
##dataset
with zipfile.ZipFile("x_train.zip", "r") as zip_ref:
    zip_ref.extractall("data")

with zipfile.ZipFile("x_test.zip", "r") as zip_ref:
    zip_ref.extractall("data")

# %%
df = pd.read_csv("y_train.csv")
df.head()
# Out:
#    id  target
# 0   1       1
# 1   2       0
# 2   3       2
# 3   4       2
# 4   5       1

# %%
##path to images

df["path"] = df["id"].apply(lambda x: f"data/img_{x}.png")

df.head()
# Out:
#    id  target            path
# 0   1       1  data/img_1.png
# 1   2       0  data/img_2.png
# 2   3       2  data/img_3.png
# 3   4       2  data/img_4.png
# 4   5       1  data/img_5.png

# %%
print(df.shape)
print(df["target"].value_counts())
print(df["path"].head())
print("Pocet existujicich souboru:", df["path"].apply(os.path.exists).sum())
# Out:
# (9770, 3)
# target
# 1    4302
# 2    3469
# 0    1647
# 3     352
# Name: count, dtype: int64
# 0    data/img_1.png
# 1    data/img_2.png
# 2    data/img_3.png
# 3    data/img_4.png
# 4    data/img_5.png
# Name: path, dtype: object
# Pocet existujicich souboru: 9770

# %%
train_df, val_df = train_test_split(
    df,
    test_size=0.2,
    stratify=df["target"],
    random_state=42
)

print("Train size:", len(train_df))
print("Validation size:", len(val_df))
# Out:
# Train size: 7816
# Validation size: 1954

# %%
train_df = train_df.copy()
val_df = val_df.copy()

train_df["target"] = train_df["target"].astype(str)
val_df["target"] = val_df["target"].astype(str)

from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# vypocet vah trid z puvodnich labelu
classes = np.array(sorted(df["target"].unique()))
class_weights_array = compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=df["target"]
)

class_weights = {int(i): float(w) for i, w in zip(classes, class_weights_array)}
print("Class weights:", class_weights)
# Out:
#         id               path target
# 7803  7804  data/img_7804.png      1
# 8901  8902  data/img_8902.png      1
# 2613  2614  data/img_2614.png      3
# 2874  2875  data/img_2875.png      2
# 3369  3370  data/img_3370.png      1

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=8,
    zoom_range=0.08,
    width_shift_range=0.05,
    height_shift_range=0.05
)

val_datagen = ImageDataGenerator(
    rescale=1./255
)

train_gen = train_datagen.flow_from_dataframe(
    train_df,
    x_col="path",
    y_col="target",
    target_size=(128, 128),
    class_mode="sparse",
    batch_size=32,
    shuffle=True
)

val_gen = val_datagen.flow_from_dataframe(
    val_df,
    x_col="path",
    y_col="target",
    target_size=(128, 128),
    class_mode="sparse",
    batch_size=32,
    shuffle=False
)

print("Train samples:", train_gen.samples)
print("Val samples:", val_gen.samples)
# Out:
# Found 7816 validated image filenames belonging to 4 classes.
# Found 1954 validated image filenames belonging to 4 classes.
# Train samples: 7816
# Val samples: 1954

# %%
##CNN model
from tensorflow.keras import regularizers

model = models.Sequential([
    layers.Input(shape=(128, 128, 3)),

    layers.Conv2D(32, (3, 3), padding="same", activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),

    layers.Conv2D(64, (3, 3), padding="same", activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),

    layers.Conv2D(128, (3, 3), padding="same", activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),

    layers.Conv2D(256, (3, 3), padding="same", activation="relu"),
    layers.BatchNormalization(),

    layers.GlobalAveragePooling2D(),

    layers.Dense(128, activation="relu", kernel_regularizer=regularizers.l2(1e-4)),
    layers.Dropout(0.4),

    layers.Dense(4, activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)



model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 126, 126, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
# Out:
# []

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=6,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=2,
    min_lr=1e-6,
    verbose=1
)

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=25,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weights
)
# Out:
# Epoch 1/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 50s 166ms/step - accuracy: 0.4145 - loss: 1.7567 - val_accuracy: 0.3552 - val_loss: 8.6600
# Epoch 2/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 35s 141ms/step - accuracy: 0.4285 - loss: 1.2132 - val_accuracy: 0.3634 - val_loss: 5.3513
# Epoch 3/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 36s 145ms/step - accuracy: 0.4324 - loss: 1.1956 - val_accuracy: 0.4253 - val_loss: 1.1970
# Epoch 4/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 34s 137ms/step - accuracy: 0.4367 - loss: 1.1843 - val_accuracy: 0.3557 - val_loss: 1.1740
# Epoch 5/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 34s 140ms/step - accuracy: 0.4291 - loss: 1.1775 - val_accuracy: 0.4401 - val_loss: 1.1594
# Epoch 6/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 34s 139ms/step - accuracy: 0.4344 - loss: 1.1659 - val_accuracy: 0.4401 - val_loss: 1.1640
# Epoch 7/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 33s 135ms/step - accuracy: 0.4358 - loss: 1.1713 - val_accuracy: 0.4401 - val_loss: 1.1639
# Epoch 8/30
# ...

# %%
print("Final train accuracy:", history.history["accuracy"][-1])
print("Final val accuracy:", history.history["val_accuracy"][-1])
# Out:
# Final train accuracy: 0.44037869572639465
# Final val accuracy: 0.4401228129863739

# %%
##Plots

plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Train accuracy")
plt.plot(history.history["val_accuracy"], label="Validation accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

##
plt.figure(figsize=(8, 5))
plt.plot(history.history["loss"], label="Train loss")
plt.plot(history.history["val_loss"], label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
##test images
test_files = [f for f in os.listdir("data") if f.endswith(".png") and f.startswith("img_")]
test_ids = []

for f in test_files:
    num = int(f.replace("img_", "").replace(".png", ""))
    if num not in df["id"].values:
        test_ids.append(num)

test_ids = sorted(test_ids)

print("Pocet testovacich obrazku:", len(test_ids))
print(test_ids[:10])
# Out:
# Pocet testovacich obrazku: 2440
# [9771, 9772, 9773, 9774, 9775, 9776, 9777, 9778, 9779, 9780]

# %%
##test data
predictions = []

for test_id in test_ids:
    img_path = f"data/img_{test_id}.png"

    img = image.load_img(img_path, target_size=(128, 128))
    img = image.img_to_array(img) / 255.0
    img = np.expand_dims(img, axis=0)

    pred = model.predict(img, verbose=0)
    pred_class = np.argmax(pred)

    predictions.append(pred_class)
